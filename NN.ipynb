# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler

 
# Step 1: Load and Preprocess the Data
 
# Load the data file (adjust the path as needed)
data = pd.read_csv('export.csv')

# Replace unwanted characters so classification is more precise
data['trackable_name'] = data['trackable_name'].astype(str).replace(r'[\n\r\'"0123456789*,.<>/?:;-_`~=+]+', '', regex=True)

# Convert the trackable_value to numeric
data['trackable_value'] = pd.to_numeric(data['trackable_value'], errors='coerce')
# Drop any rows where conversion failed
data = data.dropna(subset=['trackable_value'])

 
# Step 2: Create the Feature Matrix from Symptoms
 
# Filter to only include self-reported symptoms
symptoms = data[data['trackable_type'] == 'Symptom']

# Pivot the data so that each row (a patient) has one column per symptom, with the value being the average rating
symptom_matrix = symptoms.pivot_table(
    index='user_id',
    columns='trackable_name',
    values='trackable_value',
    aggfunc='mean'
).fillna(0)

 
# Step 3: Derive Ground Truth Labels from Conditions
 
# Filter to include only conditions
conditions = data[data['trackable_type'] == 'Condition']

# For each patient, select their primary condition
# Use the mode (most frequently reported condition) as the label
def mode_func(x):
    try:
        return x.mode()[0]
    except:
        return np.nan

condition_labels = conditions.groupby('user_id')['trackable_name'].agg(mode_func)
condition_labels = condition_labels.dropna()

 
# Step 4: Merge Features and Labels
 
# Merge the symptom fingerprint with the condition labels
df = symptom_matrix.merge(condition_labels.rename('condition'), left_index=True, right_index=True)
df = df.reset_index()
print("Merged dataset shape:", df.shape)
# Calculate frequency of each condition
condition_counts = df['condition'].value_counts()

# Keep only conditions with at least 2 samples for train/test split
valid_conditions = condition_counts[condition_counts >= 2].index
df = df[df['condition'].isin(valid_conditions)]
 
# Step 5: Prepare Data for Classification
 
# Separate features (X) and labels (y). Drop the user_id
X = df.drop(['user_id', 'condition'], axis=1).values
y = df['condition'].values

# Standardize the feature values
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# To later visualize the split, record the original indices
indices = np.arange(len(y))
# Split into training (80%) and test (20%) sets. Stratify by the condition label
X_train, X_test, y_train, y_test, idx_train, idx_test = train_test_split(
    X_scaled, y, indices, test_size=0.2, random_state=42, stratify=y
)

 
# Step 6: Train the Classifier
 
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)

# Evaluate the classifier on the test set
y_pred = clf.predict(X_test)
print("Test Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# /var/folders/0w/y9_hq1y152l9bvcl14hp3bwh0000gn/T/ipykernel_20186/230479774.py:15: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('export.csv')
# Merged dataset shape: (9038, 5848)
# Test Accuracy: 0.13827893175074185
# Classification Report:
#                                               precision    recall  f1-score   support
#
#                                                    0.20      0.49      0.29       266
#                                                    0.00      0.00      0.00         1
#                                    disorders       0.00      0.00      0.00         9
#                                       issues       0.00      0.00      0.00         1
#                      sleep behavior disorder       0.00      0.00      0.00         1
#                                            -       0.00      0.00      0.00         6
#                                       abesia       0.00      0.00      0.00         2
#                                      ace ain       0.00      0.00      0.00         1
#                                        aches       0.00      0.00      0.00         1
#                                  achy joints       0.00      0.00      0.00         0
#                                   achycardia       0.00      0.00      0.00         5
#                                   acial pain       0.00      0.00      0.00         1
#                                     ack pain       0.06      0.03      0.04        34
#                                  acroiliitis       0.00      0.00      0.00         1
#                                 actor  eiden       0.00      0.00      0.00         1
#                           actose intolerance       0.00      0.00      0.00         3
#                                    adhesions       0.00      0.00      0.00         1
#                              adrenal fatigue       0.00      0.00      0.00         8
#                                          ain       0.00      0.00      0.00         5
#             ainful intercourse (dyspareunia)       0.00      0.00      0.00         1
#                                     air loss       0.00      0.00      0.00         2
#                                       alaise       0.00      0.00      0.00         1
#                              alance problems       0.00      0.00      0.00         2
#                                     alf pain       0.00      0.00      0.00         0
#                         alindromic heumatism       0.00      0.00      0.00         1
#                                    allodynia       0.00      0.00      0.00         1
#                                    allstones       0.00      0.00      0.00         1
#                   amilial editerranean fever       0.00      0.00      0.00         1
#                                  ancreatitis       0.00      0.00      0.00         1
#                                       andida       0.00      0.00      0.00         1
#                             andida vergrowth       0.00      0.00      0.00         1
#                                        anger       0.00      0.00      0.00         1
#                            anhypopituitarism       0.00      0.00      0.00         1
#                                 anic attacks       0.00      0.00      0.00         7
#                                anic disorder       0.00      0.00      0.00         4
#                                   anker sore       0.00      0.00      0.00         1
#                             anxiety disorder       0.00      0.00      0.00         3
#                    ar infection (middle ear)       0.00      0.00      0.00         1
#                                   arcoidosis       0.00      0.00      0.00         3
#                                    arcolepsy       0.25      0.11      0.15         9
#                                ardiomyopathy       0.00      0.00      0.00         1
#                                   aresthesia       0.00      0.00      0.00         1
#                               arfan syndrome       0.00      0.00      0.00         1
#                            arkinsons disease       0.00      0.00      0.00         2
#                                     arm pain       0.00      0.00      0.00         1
#                        arpal tunnel syndrome       0.00      0.00      0.00         4
#                                     arthrtis       0.00      0.00      0.00         2
#                                    artonella       0.00      0.00      0.00         1
#                             as and gas pains       0.00      0.00      0.00         3
#                                    asculitis       0.00      0.00      0.00         2
#                                    ashimotos       0.00      0.00      0.00         1
#                            ashimotos disease       0.08      0.06      0.07        33
#                        ashimotos thyroiditis       0.00      0.00      0.00         9
#                             asovagal syncope       0.00      0.00      0.00         4
#                                    aspergers       0.00      0.00      0.00         1
#                    ast ell ctivation yndrome       0.00      0.00      0.00        12
#                                     astritis       0.00      0.00      0.00         6
#                     astrointestinal bleeding       0.00      0.00      0.00         1
#                         astrointestinal pain       0.00      0.00      0.00         0
#                                 astroparesis       0.00      0.00      0.00        24
#                                       atigue       0.00      0.00      0.00        51
#                              ating disorders       0.00      0.00      0.00         2
#                                        ausea       0.10      0.09      0.10        11
#                       autoimmune thyroiditis       0.00      0.00      0.00         1
#                                      aw pain       0.00      0.00      0.00         1
#                                     ay fever       0.00      0.00      0.00         1
#                              aynauds disease       0.50      0.08      0.13        13
#                            aynauds henomenon       0.00      0.00      0.00         1
#                            bdominal igraines       0.00      0.00      0.00         1
#                                bdominal pain       0.00      0.00      0.00         9
#                                      behcets       0.00      0.00      0.00         1
#                                       besity       0.00      0.00      0.00         1
#                                     bloating       0.00      0.00      0.00         4
#                                    brain fog       0.25      0.12      0.17         8
#                               bsence seizure       0.00      0.00      0.00         1
#                 bsessive-compulsive disorder       0.00      0.00      0.00         8
#                                 burning skin       0.00      0.00      0.00         1
#                                     chalasia       0.00      0.00      0.00         1
#                          charcot marie tooth       0.00      0.00      0.00         1
#                              chest tightness       0.00      0.00      0.00         1
#                      chizoaffective disorder       0.00      0.00      0.00         1
#                                 chizophrenia       1.00      0.50      0.67         2
#                       chronic abdominal pain       0.00      0.00      0.00         1
#                              chronic fatigue       0.00      0.00      0.00         3
#                             chronic migraine       0.00      0.00      0.00         1
#                        chronic pain syndrome       0.00      0.00      0.00         2
#                                      ciatica       0.08      0.14      0.11         7
#                                    cid eflux       0.00      0.00      0.00         5
#                                   cleroderma       0.00      0.00      0.00         1
#                                          cne       0.00      0.00      0.00         6
#                                      coeliac       0.00      0.00      0.00         1
#                                     coliosis       0.00      0.00      0.00         9
#                                    confusion       0.00      0.00      0.00         1
#                                        cough       0.00      0.00      0.00         1
#                                     csf leak       0.00      0.00      0.00         1
#                               cute sinusitis       0.00      0.00      0.00         1
#                                        czema       0.25      0.12      0.17         8
#                              ddisons disease       0.00      0.00      0.00         5
#                                   denomyosis       0.00      0.00      0.00         3
#                        diopathic hypersomnia       0.30      0.25      0.27        12
#            diopathic ntracranial ypertension       0.00      0.00      0.00         3
#        diopathic thrombocytopenic purpura ()       0.00      0.00      0.00         1
#                          drenal nsufficiency       0.00      0.00      0.00         2
#                                        dult        0.00      0.00      0.00         5
#                           dult tills disease       0.00      0.00      0.00         1
#                                      ead ain       0.00      0.00      0.00         2
#                                      eadache       0.00      0.00      0.00         3
#                                     eadaches       0.11      0.12      0.11        17
#                                      eakness       0.00      0.00      0.00         1
#                                  earing loss       0.00      0.00      0.00         1
#                             eart arrhythmias       0.00      0.00      0.00         1
#                            eart palpitations       0.00      0.00      0.00         2
#                                     eartburn       0.00      0.00      0.00         1
#                easonal affective disorder ()       0.00      0.00      0.00         1
#                     east infection (vaginal)       0.00      0.00      0.00         1
#                                     eck pain       0.25      0.12      0.17         8
#                               een depression       0.00      0.00      0.00         1
#                                        eflux       0.00      0.00      0.00         1
#                            eft shoulder pain       0.00      0.00      0.00         1
#                                      eg pain       0.00      0.00      0.00         2
#                       egenerative isc isease       0.00      0.00      0.00         8
#                       egeners granulomatosis       0.00      0.00      0.00         1
#                               ehcets disease       0.40      0.22      0.29         9
#                               eizure isorder       0.00      0.00      0.00         1
#                                eliac disease       0.00      0.00      0.00        11
#                      elvic floor dysfunction       0.00      0.00      0.00         1
#                                   emorrhoids       0.00      0.00      0.00         1
#                                   emory loss       0.00      0.00      0.00         1
#                                    endinitis       0.00      0.00      0.00         1
#                  eneralized anxiety disorder       0.00      0.00      0.00        20
#                              eneralized pain       0.00      0.00      0.00         1
#                              enieres disease       0.00      0.00      0.00         3
#                              ension headache       0.00      0.00      0.00         3
#                     ensory rocessing isorder       0.00      0.00      0.00         1
#                              enstrual cramps       0.00      0.00      0.00         1
#                                enstrual ycle       0.00      0.00      0.00         2
#                                  ental ealth       0.00      0.00      0.00         1
#                                ental illness       0.00      0.00      0.00         1
#                          entral ensitization       0.00      0.00      0.00         0
#                                 epressed ood       0.00      0.00      0.00         1
#                                    epression       0.13      0.13      0.13        97
#                             epressionanxiety       0.00      0.00      0.00         1
#                                  eptic ulcer       0.00      0.00      0.00         1
#                                erebral palsy       0.00      0.00      0.00         1
#                                        eriod       0.00      0.00      0.00         1
#                         eripheral neuropathy       0.50      0.20      0.29         5
#                                    ermatitis       0.00      0.00      0.00         0
#                               ermatomyositis       0.00      0.00      0.00         1
#                                erniated disk       0.00      0.00      0.00         2
#                              ernicious nemia       0.00      0.00      0.00         3
#                                    erve pain       0.00      0.00      0.00         2
#                          ervical spondylosis       0.00      0.00      0.00         1
#                        estless legs syndrome       0.00      0.00      0.00         3
#                       eurocardiogenic yncope       0.00      0.00      0.00         1
#                                         ever       0.00      0.00      0.00         2
#                    ew aily ersistent eadache       0.00      0.00      0.00         0
#                 excessive daytime sleepiness       0.00      0.00      0.00         1
#                                 fibromyalgia       0.00      0.00      0.00         1
#                                  fibromylgia       0.00      0.00      0.00         0
#                             gender dysphoria       0.00      0.00      0.00         1
#                           gluten intolerance       0.00      0.00      0.00         1
#                                   goraphobia       0.00      0.00      0.00         1
#                                    hand pain       0.00      0.00      0.00         1
#                       hashimotos thyroiditis       0.00      0.00      0.00         1
#                          hemiplegic migraine       0.00      0.00      0.00         1
#                                    hest pain       0.00      0.00      0.00         1
#                          heumatoid arthritis       0.16      0.11      0.13        35
#                           hiari malformation       0.00      0.00      0.00         4
#                                      hiplash       0.00      0.00      0.00         1
#                          hlers anlos yndrome       0.00      0.00      0.00         4
#                         hlers-anlos syndrome       0.12      0.07      0.09        45
#                        hondromalacia patella       0.00      0.00      0.00         1
#                                 houlder pain       0.00      0.00      0.00         1
#                              hronic ack pain       0.00      0.00      0.00         5
#                                   hronic ain       0.14      0.06      0.08        17
#                           hronic ancreatitis       0.00      0.00      0.00         1
#                              hronic astritis       0.00      0.00      0.00         1
#                                 hronic ausea       0.00      0.00      0.00         1
#                          hronic constipation       0.00      0.00      0.00         3
#                                 hronic cough       0.00      0.00      0.00         1
#                       hronic daily headaches       0.00      0.00      0.00         7
#                   hronic egional ain yndrome       0.00      0.00      0.00         1
#                      hronic fatigue syndrome       0.04      0.03      0.04        58
#                     hronic hives (urticaria)       0.33      0.50      0.40         4
#                              hronic igraines       0.00      0.00      0.00        13
#                               hronic illness       0.00      0.00      0.00         1
#                        hronic kidney disease       0.00      0.00      0.00         1
#                           hronic pelvic pain       0.00      0.00      0.00         2
#                             hronic sinusitis       0.00      0.00      0.00         2
#                                   hronic yme       0.00      0.00      0.00         1
#                                  hypersomnia       0.00      0.00      0.00         1
#                                      iabetes       0.00      0.00      0.00         3
#                                      iarrhea       0.00      0.00      0.00         4
#                                 iatal hernia       0.00      0.00      0.00         1
#                                      ib pain       0.00      0.00      0.00         0
#                                     ibro fog       0.00      0.00      0.00         1
#                                  ibromyalgia       0.13      0.22      0.17       126
#                            ickle cell anemia       0.00      0.00      0.00         1
#                      idradenitis suppurativa       0.00      0.00      0.00         2
#                           igh blood pressure       0.00      0.00      0.00         1
#            igh blood pressure (hypertension)       0.00      0.00      0.00         2
#                                      igraine       0.00      0.00      0.00        19
#                            igraine with aura       0.00      0.00      0.00         2
#                                          ild       0.00      0.00      0.00         1
#              inappropriate sinus tachycardia       0.00      0.00      0.00         1
#                                      innitus       0.00      0.00      0.00         1
#                               inus headaches       0.00      0.00      0.00         0
#                                       ip ain       0.00      0.00      0.00         2
#                              ipolar disorder       0.00      0.00      0.00         3
#                                 ipolar type        0.00      0.00      0.00         2
#                                     iredness       0.00      0.00      0.00         2
#                                 irritability       0.00      0.00      0.00         1
#                         istamine intolerance       0.00      0.00      0.00         0
#                          itochondrial isease       0.00      0.00      0.00         0
#               ixed connective tissue disease       0.00      0.00      0.00         3
#                                     izziness       0.00      0.00      0.00         2
#                                      jogrens       0.00      0.00      0.00         1
#                             jogrens syndrome       0.00      0.00      0.00         8
#                          joint hypermobility       0.00      0.00      0.00         1
#                                   joint pain       0.00      0.00      0.00         8
#                                         lare       0.00      0.00      0.00         1
#                            lcerative colitis       0.31      0.29      0.30        28
#                               leep disorders       0.00      0.00      0.00         1
#                                        leepy       0.00      0.00      0.00         0
#                          lhers anlos yndrome       0.00      0.00      0.00         1
#                                     llergies       0.00      0.00      0.00         5
#                                 lurred ision       0.00      0.00      0.00         0
#                    major depressive disorder       0.00      0.00      0.00         2
#                             muscle stiffness       0.00      0.00      0.00         1
#                                   ndiagnosed       0.00      0.00      0.00         3
#       ndifferentiated onnective issue isease       0.00      0.00      0.00         3
#                                   ndigestion       0.00      0.00      0.00         1
#                                 ndometriosis       0.27      0.28      0.27        29
#                                     nee pain       0.00      0.00      0.00         1
#                                        nemia       0.00      0.00      0.00         2
#                                  nflammation       0.00      0.00      0.00         2
#                 nflammatory bowel disease ()       0.00      0.00      0.00         3
#                         nflammatory rthritis       0.00      0.00      0.00         1
#                        nkylosing spondylitis       0.12      0.09      0.11        11
#                              norexia nervosa       0.00      0.00      0.00         0
#                                      nsomnia       0.00      0.00      0.00         1
#                         nterstitial cystitis       0.00      0.00      0.00         4
#                                       nxiety       0.20      0.13      0.16        15
#                          occipital neuralgia       0.00      0.00      0.00         1
#                               oint stiffness       0.00      0.00      0.00         0
#                    oint ypermobility yndrome       0.00      0.00      0.00         2
#                                  old allergy       0.00      0.00      0.00         1
#                                       olitis       0.00      0.00      0.00         1
#                  olycystic ovary syndrome ()       0.00      0.00      0.00         2
#                             olycythemia vera       0.00      0.00      0.00         0
#                        olymyalgia rheumatica       0.00      0.00      0.00         0
#                                   ommon cold       0.00      0.00      0.00         1
#                omplex regional pain syndrome       0.00      0.00      0.00         5
#                                   onsillitis       1.00      1.00      1.00         1
#                              ood ntolerances       0.00      0.00      0.00         1
#                                      oot ain       0.00      0.00      0.00         0
#               orderline personality disorder       0.00      0.00      0.00         1
#                                       osacea       0.00      0.00      0.00         1
#                   osinophilic astroenteritis       0.00      0.00      0.00         1
#                      osinophilic esophagitis       0.00      0.00      0.00         1
#                      ost-concussion syndrome       0.00      0.00      0.00         1
#             ost-traumatic stress disorder ()       0.00      0.00      0.00         1
#        ostural rthostatic achycardia yndrome       0.00      0.00      0.00         7
#                                 ow back pain       0.00      0.00      0.00         1
#                               ower back pain       0.00      0.00      0.00         1
#                   phincter of ddi ysfunction       0.00      0.00      0.00         1
#                                      pilepsy       0.00      0.00      0.00         1
# postural orthostatic tachycardia syndrome ()       0.00      0.00      0.00         2
#                   psoclonus yoclonus yndrome       0.00      0.00      0.00         1
#                        raumatic brain injury       0.00      0.00      0.00         0
#                                raves disease       0.00      0.00      0.00         3
#                      remenstrual syndrome ()       0.00      0.00      0.00         1
#                          rigeminal neuralgia       1.00      0.50      0.67         2
#                     rimary biliary cirrhosis       0.00      0.00      0.00         1
#                                        rohns       0.00      0.00      0.00         4
#                                rohns disease       0.12      0.24      0.16        41
#                                rohn’s isease       0.00      0.00      0.00         1
#                                rotoporphyria       0.00      0.00      0.00         1
#                      rritable bowel syndrome       0.00      0.00      0.00         5
#                                     rthritis       0.00      0.00      0.00         4
#                                      ry eyes       0.00      0.00      0.00         1
#                           seudotumor cerebri       0.00      0.00      0.00         1
#                                     soriasis       0.00      0.00      0.00         6
#                           soriatic arthritis       0.00      0.00      0.00         7
#                                steoarthritis       0.00      0.00      0.00         1
#                                        sthma       0.00      0.00      0.00         4
#                 systemic lupus erythematosus       0.00      0.00      0.00         8
#                                   tomach ain       0.00      0.00      0.00         2
#                    topic dermatitis (eczema)       0.00      0.00      0.00         1
#                                         uctd       0.00      0.00      0.00         1
#                            ultiple sclerosis       0.00      0.00      0.00        19
#                                      unknown       0.00      0.00      0.00         2
#                                         upus       0.00      0.00      0.00        17
#                               upus nephritis       0.00      0.00      0.00         1
#                                    utoimmune       0.00      0.00      0.00         2
#                            utoimmune disease       0.00      0.00      0.00         1
#                          utoimmune hepatitis       0.00      0.00      0.00         1
#                 uvenile rheumatoid arthritis       0.00      0.00      0.00         1
#                                         very       0.00      0.00      0.00         1
#                                  very active       0.00      0.00      0.00         1
#                                     vomiting       0.00      0.00      0.00         0
#                           wollen lymph nodes       0.00      0.00      0.00         1
#                                    xhaustion       0.00      0.00      0.00         1
#                     yalgic encephalomyelitis       0.00      0.00      0.00         6
#                             yasthenia gravis       0.00      0.00      0.00         2
#                                  ybromyalgia       0.00      0.00      0.00         2
#                      yclic vomiting syndrome       0.00      0.00      0.00         1
#                                  yme disease       0.00      0.00      0.00        14
#                      yofascial pain syndrome       0.00      0.00      0.00         1
#                                ype  diabetes       0.00      0.00      0.00         1
#                                 ypermobility       0.00      0.00      0.00         1
#                               yperthyroidism       0.00      0.00      0.00         1
#                                ypothyroidism       0.00      0.00      0.00         6
#                                  ysautonomia       0.00      0.00      0.00         5
#                         ystemic mastocytosis       0.00      0.00      0.00         0
#                               ystic fibrosis       0.00      0.00      0.00         2
#
#                                     accuracy                           0.14      1685
#                                    macro avg       0.03      0.02      0.02      1685
#                                 weighted avg       0.10      0.14      0.10      1685
# /opt/miniconda3/envs/dl_hw/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/miniconda3/envs/dl_hw/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/miniconda3/envs/dl_hw/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/miniconda3/envs/dl_hw/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/miniconda3/envs/dl_hw/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/miniconda3/envs/dl_hw/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
def predict_condition(symptom, severity, feature_names, scaler, clf):
    
    # Create a zero vector with shape (1, number of features)
    input_vector = np.zeros((1, len(feature_names)))
    
    # Check if the symptom is present in the features
    if symptom not in feature_names:
        print(f"Symptom '{symptom}' not recognized.")
        print("Available symptoms are:")
        for feat in feature_names:
            print(f" - {feat}")
        return None
    
    # Set the input severity for the specified symptom
    idx = feature_names.index(symptom)
    input_vector[0, idx] = severity
    
    # Scale the input vector using the previously fitted scaler
    input_vector_scaled = scaler.transform(input_vector)
    
    # Predict using the trained classifier
    prediction = clf.predict(input_vector_scaled)
    return prediction[0]

# INTERACTION SECTION
# Get the list of feature names (symptoms) from the pivot table columns.
feature_names = list(symptom_matrix.columns)

# Prompt the user for input.
symptom_input = input("Enter the symptom name (exactly as in the data): ").strip()
try:
    severity_input = float(input("Enter the severity (numeric, e.g., 0 to 4): "))
except ValueError:
    print("Invalid severity input. Please enter a numeric value.")
    severity_input = None

if severity_input is not None:
    predicted_condition = predict_condition(symptom_input, severity_input, feature_names, scaler, clf)
    if predicted_condition is not None:
        print(f"Predicted Condition: {predicted_condition}")
# Out:
# Invalid severity input. Please enter a numeric value.
